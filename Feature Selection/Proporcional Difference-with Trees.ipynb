# %% [markdown]
# # Proporcional Difference
#
# Teste do método de seleção de features Proporcional Difference proposto em http://crpit.com/confpapers/CRPITV87Simeon.pdf
#
# Este método foi testado contra outros, inclusive o SentiWordNet, em:
# http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.471.5694&rep=rep1&type=pdf#page=77

# %%
# Aqui estou usando todo o corpus para selecionar as melhores features.

from utils import  *
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from collections import defaultdict
from pandas import DataFrame

# 1) Separar o corpus por classes
numRemover = NumRemover()
all_data = numRemover.fit_transform(get_data_from_db())
pos_data = numRemover.fit_transform(get_data_from_db(sentiment="PO"))["texts"]
neg_data = numRemover.fit_transform(get_data_from_db(sentiment="NG"))["texts"]
neu_data = numRemover.fit_transform(get_data_from_db(sentiment="NE"))["texts"]

# 2) Criar um vetorizer para unigrams
vectorizer = CountVectorizer(ngram_range=(1,2), stop_words= stopwords.words("portuguese"), strip_accents= "unicode")

# 3) Fazer o fit para todo o corpus
vectorizer.fit(all_data["texts"])

# 4) Pegar todo o vocabulário do corpus
vocab = list(vectorizer.vocabulary_.keys())
vocab_indexed = {value: key for key, value in vectorizer.vocabulary_.items()}

# 5) Obter as matrizes das classes
pos_matrix = vectorizer.transform(pos_data)
neg_matrix = vectorizer.transform(neg_data)
neu_matrix = vectorizer.transform(neu_data)

# 6) Obter o vetor de soma das frquencias das palavras nas classes
pos_sum = pos_matrix.sum(axis=0)
neg_sum = neg_matrix.sum(axis=0)
neu_sum = neu_matrix.sum(axis=0)

# 7) Construir um dicionario de frequencias para cada classe e calcular o PD de cada uma
# função que calcula o PD
pd = lambda c1, c2, c3: max([(c1 - c2 - c3)/(c1 + c2 + c3), (c2 - c1 - c3)/(c1 + c2 + c3), (c3 - c2 - c1)/(c1 + c2 + c3)])
freq_dict = [ {"PO": pos_sum[0,index], "NG": neg_sum[0,index], "NE": neu_sum[0,index], "PD": pd(pos_sum[0,index], neg_sum[0,index], neu_sum[0,index])} for index in vocab_indexed.keys()]
freq_df = DataFrame(data = freq_dict, index= vocab_indexed.values())
freq_df = freq_df[["PO", "NG", "NE", "PD"]] # Reordenando as colunas do data frame

# 8) Selecionar as melhores features
threshold = 1
selected = freq_df[freq_df["PD"] == threshold].index.values
selected = list(selected)
print("Dimensionalidade: ", len(selected))

# 9) Avaliar o desempenho dos classificadores utilizando as features selecionadas
unigram_vectorizer = CountVectorizer(ngram_range=(1,2), stop_words= stopwords.words("portuguese"), strip_accents= "unicode", vocabulary= selected)
# evaluate(all_data, unigram_vectorizer, 10)
# Out:
# Dimensionalidade:  23444

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

print("Simple decision Tree")
run_cross_validation2(all_data, unigram_vectorizer, DecisionTreeClassifier(criterion="gini"))
# Out:
# Simple decision Tree
# Cross Validation:
# Fold  0  - Acuracia:  0.518867924528
# Fold  1  - Acuracia:  0.538461538462
# Fold  2  - Acuracia:  0.586538461538
# Fold  3  - Acuracia:  0.519230769231
# Fold  4  - Acuracia:  0.557692307692
# Fold  5  - Acuracia:  0.528846153846
# Fold  6  - Acuracia:  0.528846153846
# Fold  7  - Acuracia:  0.509615384615
# Fold  8  - Acuracia:  0.548076923077
# Fold  9  - Acuracia:  0.519230769231
# Accuracia media:  0.535540638607
# Desvio padrão:  0.0219748005477

# %%
print("Random Forest")
run_cross_validation2(all_data, unigram_vectorizer, RandomForestClassifier(criterion="gini", n_estimators=50))
# Out:
# Random Forest
# Cross Validation:
# Fold  0  - Acuracia:  0.396226415094
# Fold  1  - Acuracia:  0.346153846154
# Fold  2  - Acuracia:  0.461538461538
# Fold  3  - Acuracia:  0.432692307692
# Fold  4  - Acuracia:  0.490384615385
# Fold  5  - Acuracia:  0.413461538462
# Fold  6  - Acuracia:  0.394230769231
# Fold  7  - Acuracia:  0.384615384615
# Fold  8  - Acuracia:  0.413461538462
# Fold  9  - Acuracia:  0.413461538462
# Accuracia media:  0.414622641509
# Desvio padrão:  0.0382285092259

# %%
# Aqui usamos somente o conjunto de treinamento para selecionar as melhores features com PD

from utils import  *
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from collections import defaultdict
from pandas import DataFrame

from sklearn.model_selection import train_test_split
import random 

# 1) Separar o corpus por classes
numRemover = NumRemover()
all_data = numRemover.fit_transform(get_data_from_db())
seed = int(random.uniform(0, 100))
train_ratio = 0.7
train, test, ytrain, ytest = train_test_split(all_data, all_data["labels"], train_size = train_ratio, stratify = all_data["labels"], random_state = seed)

pos_data = train[train["labels"] == "PO"]["texts"]
neg_data = train[train["labels"] == "NG"]["texts"]
neu_data = train[train["labels"] == "NE"]["texts"]

# 2) Criar um vetorizer para unigrams
vectorizer = CountVectorizer(ngram_range=(1,2), stop_words= stopwords.words("portuguese"), strip_accents= "unicode")

# 3) Fazer o fit para todo o corpus
vectorizer.fit(train["texts"])

# 4) Pegar todo o vocabulário do corpus
vocab = list(vectorizer.vocabulary_.keys())
vocab_indexed = {value: key for key, value in vectorizer.vocabulary_.items()}

# 5) Obter as matrizes das classes
pos_matrix = vectorizer.transform(pos_data)
neg_matrix = vectorizer.transform(neg_data)
neu_matrix = vectorizer.transform(neu_data)

# 6) Obter o vetor de soma das frquencias das palavras nas classes
pos_sum = pos_matrix.sum(axis=0)
neg_sum = neg_matrix.sum(axis=0)
neu_sum = neu_matrix.sum(axis=0)

# 7) Construir um dicionario de frequencias para cada classe e calcular o PD de cada uma
# função que calcula o PD
pd = lambda c1, c2, c3: max([(c1 - c2 - c3)/(c1 + c2 + c3), (c2 - c1 - c3)/(c1 + c2 + c3), (c3 - c2 - c1)/(c1 + c2 + c3)])
freq_dict = [ {"PO": pos_sum[0,index], "NG": neg_sum[0,index], "NE": neu_sum[0,index], "PD": pd(pos_sum[0,index], neg_sum[0,index], neu_sum[0,index])} for index in vocab_indexed.keys()]
freq_df = DataFrame(data = freq_dict, index= vocab_indexed.values())
freq_df = freq_df[["PO", "NG", "NE", "PD"]] # Reordenando as colunas do data frame

# 8) Selecionar as melhores features
threshold = 1
selected = freq_df[freq_df["PD"] >= threshold].index.values
selected = list(selected)
print("Dimensionalidade: ", len(selected))

# 9) Avaliar o desempenho dos classificadores utilizando as features selecionadas
unigram_vectorizer = CountVectorizer(ngram_range=(1,2), stop_words= stopwords.words("portuguese"), strip_accents= "unicode", vocabulary= selected)
evaluate(all_data, unigram_vectorizer, 10)
# Out:
# Dimensionalidade:  17728
# Naive Bayes---------------------------------
# Cross Validation:
# Accuracia media:  0.635359216255
# Desvio padrão:  0.0341172871526
#
# MaxEnt--------------------------------------
# Cross Validation:
# Accuracia media:  0.732220609579
# Desvio padrão:  0.0476956566556
#
# SVM-----------------------------------------
# Cross Validation:
# Accuracia media:  0.593196661829
# Desvio padrão:  0.0314476741683

# %%
# Aqui usamos somente o conjunto de treinamento para selecionar as melhores features com PD

from utils import  *
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from collections import defaultdict
from pandas import DataFrame

from sklearn.model_selection import train_test_split
import random 

# 1) Separar o corpus por classes
numRemover = NumRemover()
all_data = numRemover.fit_transform(get_data_from_db())
seed = int(random.uniform(0, 100))
train_ratio = 0.7
train, test, ytrain, ytest = train_test_split(all_data, all_data["labels"], train_size = train_ratio, stratify = all_data["labels"], random_state = seed)

pos_data = train[train["labels"] == "PO"]["texts"]
neg_data = train[train["labels"] == "NG"]["texts"]
neu_data = train[train["labels"] == "NE"]["texts"]

# 2) Criar um vetorizer para unigrams
vectorizer = CountVectorizer(ngram_range=(1,2), stop_words= stopwords.words("portuguese"), strip_accents= "unicode")

# 3) Fazer o fit para todo o corpus
vectorizer.fit(train["texts"])

# 4) Pegar todo o vocabulário do corpus
vocab = list(vectorizer.vocabulary_.keys())
vocab_indexed = {value: key for key, value in vectorizer.vocabulary_.items()}

# 5) Obter as matrizes das classes
pos_matrix = vectorizer.transform(pos_data)
neg_matrix = vectorizer.transform(neg_data)
neu_matrix = vectorizer.transform(neu_data)

# 6) Obter o vetor de soma das frquencias das palavras nas classes
pos_sum = pos_matrix.sum(axis=0)
neg_sum = neg_matrix.sum(axis=0)
neu_sum = neu_matrix.sum(axis=0)

# 7) Construir um dicionario de frequencias para cada classe e calcular o PD de cada uma
# função que calcula o PD
pd = lambda c1, c2, c3: max([(c1 - c2 - c3)/(c1 + c2 + c3), (c2 - c1 - c3)/(c1 + c2 + c3), (c3 - c2 - c1)/(c1 + c2 + c3)])
freq_dict = [ {"PO": pos_sum[0,index], "NG": neg_sum[0,index], "NE": neu_sum[0,index], "PD": pd(pos_sum[0,index], neg_sum[0,index], neu_sum[0,index])} for index in vocab_indexed.keys()]
freq_df = DataFrame(data = freq_dict, index= vocab_indexed.values())
freq_df = freq_df[["PO", "NG", "NE", "PD"]] # Reordenando as colunas do data frame

# 8) Selecionar as melhores features
threshold = 1
selected = freq_df[freq_df["PD"] >= threshold].index.values
selected = list(selected)
print("Dimensionalidade: ", len(selected))

# 9) Avaliar o desempenho dos classificadores utilizando as features selecionadas
unigram_vectorizer = CountVectorizer(ngram_range=(1,2), stop_words= stopwords.words("portuguese"), strip_accents= "unicode", vocabulary= selected)
evaluate(all_data, unigram_vectorizer, 10)
# Out:
# Dimensionalidade:  17884
# Naive Bayes---------------------------------
# Cross Validation:
# Accuracia media:  0.659379535559
# Desvio padrão:  0.0346981096333
#
# MaxEnt--------------------------------------
# Cross Validation:
# Accuracia media:  0.721770682148
# Desvio padrão:  0.0315928363612
#
# SVM-----------------------------------------
# Cross Validation:
# Accuracia media:  0.541364296081
# Desvio padrão:  0.0429905900412

# %%
selected
# Out:
# ['aabandonoo pre',
#  'abafaram dentro',
#  'abaixo medias',
#  'abalo conviccoes',
#  'abandonada diante',
#  'abandonando paleto',
#  'abandonar desacelerar',
#  'abandono meta',
#  'abandono metas',
#  'abandono sete',
#  'abandonou estrategia',
#  'abastecido petrobras',
#  'abastecimento empresa',
#  'abastecimento petrobras',
#  'abastecimento pp',
#  'abastecimento sao',
#  'aberta ex',
#  'aberta nome',
#  'aberto acredita',
#  'aberto aqui',
#  'aberto calcadao',
#  'aberto revista',
#  'abertura campanha',
#  'abertura startups',
#  'abordados relatorio',
#  'abordagem distorce',
#  'abordagem fere',
#  'abordou corrupcao',
#  'abordou programas',
#  'aborto criminalizacao',
#  'aborto descriminalizacao',
#  'abra mente',
#  'abracada marina',
#  'abracaram presidente',
#  'abre brecha',
#  'abre pequeno',
#  'abrem fecham',
#  'abreu lima',
#  'abril deste',
#  'abrir mao',
#  'abrir ultimos',
#  'absoluta certeza',
#  'absoluta incapacidade',
#  'absoluta solucao',
#  'absolutamente contra',
#  'absolutamente divulgados',
#  'absolutamente estranha',
#  'absolutamente inaceitavel',
#  'absolutamente necessario',
#  'absolutamente normal',
#  'absolutamente vergonhoso',
#  'abstrata futuro',
#  'absurdo disse',
#  'absurdo falta',
#  'acabando petrobras',
#  'acabando ultimo',
#  'acabar disse',
#  'acabar mercosul',
#  'acabar piorando',
#  'acabar programas',
#  'acabar reeleicao',
#  'acabara programa',
#  'acabavam impedindo',
#  'acabe sensacao',
#  'acabei identificando',
#  'acabou antes',
#  'acabou artificial',
#  'acabou desmoralizar',
#  'acabou governo',
#  'acabou leva',
#  'acabou menos',
#  'acalorado noite',
#  'acao conjunta',
#  'acao sob',
#  'acatar informacoes',
#  'acatou solicitacao',
#  'aceitar qualquer',
#  'aceitar ser',
#  'aceitavel dormir',
#  'aceito provocacoes',
#  'aceitou critica',
#  'aceitou fazer',
#  'acelerada gastos',
#  'aceno agronegocio',
#  'acenou brevemente',
#  'acenou militantes',
#  'acentuar discurso',
#  'acerta penalti',
#  'acertar dois',
#  'acerto escolhas',
#  'acertou regime',
#  'acervo desqualificacoes',
#  'acervo repertorio',
#  'acesso condicoes',
#  'acesso dados',
#  'acesso depoimentos',
#  'acesso imediato',
#  'acesso informacao',
#  'acesso informacoes',
#  'acesso integral',
#  'acesso internet',
#  'acesso material',
#  'acesso processo',
#  'acha estranho',
#  'acha plataforma',
#  'acham vao',
#  'achar so',
#  'achava campanha',
#  'achavamos iria',
#  'achei agenda',
#  'acho acabar',
#  'acho aumentou',
#  'acho brasil',
#  'acho caminhado',
#  'acho estao',
#  'acho existe',
#  'acho governos',
#  'acho nao',
#  'acho sentar',
#  'acho tao',
#  'acho voto',
#  'acidentalmente havia',
#  'acidente agosto',
#  'acidente aviao',
#  'acidente deslize',
#  'acido critico',
#  'acima intencoes',
#  'acima teto',
#  'acionista sabesp',
#  'acirrada dilma',
#  'acoes acoes',
#  'acoes empresas',
#  'acoes governo',
#  'acoes instituicoes',
#  'acoes penais',
#  'acoes posicoes',
#  'acoes programa',
#  'acoes recursos',
#  'acoes serem',
#  'acoes sucroalcooleiras',
#  'acometeu estatal',
#  'acompanhada candidato',
#  'acompanhada eliane',
#  'acompanhada lindberg',
#  'acompanhada ministros',
#  'acompanhado governador',
#  'acompanhado link',
#  'acompanhar parada',
#  'acompanharam neste',
#  'acompanhava parada',
#  'acompanhou banda',
#  'acompanhou criterios',
#  'acompanhou divulgacao',
#  'acontece casa',
#  'acontece comigo',
#  'acontece entorno',
#  'acontece governo',
#  'acontece perdem',
#  'acontece porque',
#  'acontecendo marca',
#  'acontecer afirmou',
#  'acontecer nao',
#  'acontecer voces',
#  'acontecera junho',
#  'aconteceram debaixo',
#  'acontecesse empresas',
#  'aconteceu apos',
#  'aconteceu durante',
#  'aconteceu programa',
#  'acordar pesadelo',
#  'acordo agencia',
#  'acordo ago',
#  'acordo assessores',
#  'acordo assessoria',
#  'acordo baixar',
#  'acordo candidata',
#  'acordo candidato',
#  'acordo datafolha',
#  'acordo depoimento',
#  'acordo despacho',
#  'acordo dilma',
#  'acordo diretrizes',
#  'acordo instituto',
#  'acordo material',
#  'acordo organizadores',
#  'acordo pesquisa',
#  'acordo pesquisas',
#  'acordo professor',
#  'acordo psdb',
#  'acordo recentes',
#  'acordo reportagem',
#  'acordo revista',
#  'acordo tucano',
#  'acordou disse',
#  'acre ainda',
#  'acre estado',
#  'acre relembrou',
#  'acredita campanha',
#  'acredita faltam',
#  'acredita ha',
#  'acredita importancia',
#  'acredita intencoes',
#  'acredita psdb',
#  'acreditamos propaganda',
#  'acreditar acerto',
#  'acreditar dilma',
#  'acreditar governo',
#  'acreditar naquilo',
#  'acreditar possibilidade',
#  'acreditar psdb',
#  'acreditar so',
#  'acreditar vai',
#  'acreditar vamos',
#  'acredito chegou',
#  'acredito dados',
#  'acredito deus',
#  'acredito ninguem',
#  'acredito posso',
#  'acredito presidente',
#  'acrescentando ainda',
#  'acrescentando pre',
#  'acrescentando saldo',
#  'acrescido patrimonio',
#  'acucar negocio',
#  'acumulada oposicao',
#  'acusacao cabral',
#  'acusacao citacao',
#  'acusacao desse',
#  'acusacao marina',
#  'acusacao ministerio',
#  'acusacao sobre',
#  'acusacao troca',
#  'acusacoes aplicavel',
#  'acusacoes chulas',
#  'acusacoes contra',
#  'acusacoes eduardo',
#  'acusacoes envolvimento',
#  'acusacoes feitas',
#  'acusacoes ministerio',
#  'acusacoes nao',
#  'acusacoes precisam',
#  'acusacoes preso',
#  'acusacoes priorizar',
#  'acusacoes sido',
#  'acusacoes sobre',
#  'acusada ser',
#  'acusado candidato',
#  'acusado disse',
#  'acusado manipular',
#  'acusado quero',
#  'acusado tucano',
#  'acusados nao',
#  'acusando discutindo',
#  'acusando orgao',
#  'acusava adversarios',
#  'acusou governador',
#  'acusou indiretamente',
#  'acusou nesta',
#  'acusou neste',
#  'acusou noite',
#  'adelmo genro',
#  'adelmo saiu',
#  'adentrou atual',
#  'adequada disse',
#  'adesao marina',
#  'adesivo candidato',
#  'adesivos campanha',
#  'adiado ha',
#  'adiamento reformas',
#  'adianta dizer',
#  'adianta governo',
#  'adianta querer',
#  'adiantara numeros',
#  'adiantou reuters',
#  'admar gonzaga',
#  'administracao companhia',
#  'administracao estatal',
#  'administracao federal',
#  'administracao governador',
#  'administracao marina',
#  'administracao petista',
#  'administracao profissional',
#  'administrador publico',
#  'administrativo companhia',
#  'administrativo podem',
#  'administrativos politicas',
#  'administrativos portanto',
#  'admira la',
#  'admite farpas',
#  'admitido primeira',
#  'admitido tambem',
#  'admitiu nesta',
#  'admitiu ter',
#  'adolescente conseguia',
#  'adota discurso',
#  'adota independencia',
#  'adota postura',
#  'adotada governo',
#  'adotado desde',
#  'adotado medidas',
#  'adotado tatica',
#  'adotando modelito',
#  'adotou contra',
#  'adotou discurso',
#  'adotou estrategia',
#  'adotou nova',
#  'adotou novo',
#  'adotou solucao',
#  'adotou tatica',
#  'adquiri conhecimento',
#  'adversaria campanha',
#  'adversaria candidata',
#  'adversaria citar',
#  'adversaria deixar',
#  'adversaria disse',
#  'adversaria fato',
#  'adversaria intensificaram',
#  'adversaria marina',
#  'adversaria petista',
#  'adversaria pois',
#  'adversaria presidente',
#  'adversaria pretende',
#  'adversaria psb',
#  'adversaria retrucou',
#  'adversaria ser',
#  'adversarias pt',
#  'adversario alexandre',
#  'adversario disputa',
#  'adversario diz',
#  'adversario duas',
#  'adversario manifestacao',
#  'adversario paulo',
#  'adversario proximo',
#  'adversario respeitar',
#  'adversarios aecio',
#  'adversarios afirmou',
#  'adversarios alckmin',
#  'adversarios campanha',
#  'adversarios diante',
#  'adversarios dilma',
#  'adversarios disputa',
#  'adversarios estao',
#  'adversarios marina',
#  'adversarios montaram',
#  'adversarios nesta',
#  'adversarios parece',
#  'adversarios praticam',
#  'adversarios recursos',
#  'adversarios reeleito',
#  'adversarios reiterado',
#  'adversarios supostamente',
#  'adversarios ultimos',
#  'adversarios vai',
#  'adversarios vez',
#  'advogado padilha',
#  'advogado professor',
#  'advogado reu',
#  'advogados parou',
#  'aecio adota',
#  'aecio adotou',
#  'aecio agora',
#  'aecio alcanca',
#  'aecio amigo',
#  'aecio apontou',
#  'aecio apos',
#  'aecio base',
#  'aecio cade',
#  'aecio candidatura',
#  'aecio centenas',
#  'aecio chegou',
#  'aecio citou',
#  'aecio cobra',
#  'aecio comprometeu',
#  'aecio consegue',
#  'aecio consolidar',
#  'aecio continuou',
#  'aecio criticou',
#  'aecio defendeu',
#  'aecio deixou',
#  'aecio despesas',
#  'aecio deveria',
#  'aecio eleito',
#  'aecio empresas',
#  'aecio encerrou',
#  'aecio enquanto',
#  'aecio estado',
#  'aecio faz',
#  'aecio fez',
#  'aecio hoje',
#  'aecio intensificado',
#  'aecio lado',
#  'aecio lamentou',
#  'aecio lembrando',
#  'aecio lembrou',
#  'aecio manteve',
#  'aecio minas',
#  'aecio nao',
#  'aecio passou',
#  'aecio petista',
#  'aecio pior',
#  'aecio primeiro',
#  'aecio problema',
#  'aecio questionou',
#  'aecio rebateu',
#  'aecio recebido',
#  'aecio reconhecido',
#  'aecio rejeicao',
#  'aecio relacao',
#  'aecio respondeu',
#  'aecio retomou',
#  'aecio sao',
#  'aecio seguiu',
#  'aecio sempre',
#  'aecio simulacao',
#  'aecio sobre',
#  'aecio ter',
#  'aecio terceiro',
#  'aecio vinha',
#  'aecio visita',
#  'aecio visitou',
#  'aereo agosto',
#  'aereo envolvido',
#  'aereo marina',
#  'aereo matou',
#  'aereo ultimo',
#  'aeroporto aecio',
#  'aeroporto fazenda',
#  'aeroporto maraba',
#  'aeroporto membros',
#  'afago aecio',
#  'afastado apos',
#  'afastamento deputado',
#  'afastamento imediatamente',
#  'afastar autoridade',
#  'afastou diretores',
#  'afetada minimo',
#  'afetados inclui',
#  'afetar resultado',
#  'afetaram diretamente',
#  'afeto mim',
#  'afeto politico',
#  'afiadas robaina',
#  'afilhado ex',
#  'afinal candidata',
#  'afinal pais',
#  'afinidade disse',
#  'afirma ainda',
#  'afirma autonomia',
#  'afirma candidato',
#  'afirma cerqueira',
#  'afirma coisa',
#  'afirma despolitizacao',
#  'afirma dilma',
#  'afirma diz',
#  'afirma economist',
#  'afirma eleicao',
#  'afirma ex',
#  'afirma gente',
#  'afirma melhor',
#  'afirma participou',
#  'afirma petroleo',
#  'afirma presidente',
#  'afirma proposta',
#  'afirma relatos',
#  'afirma tambem',
#  'afirmacao dilma',
#  'afirmacao faz',
#  'afirmacao incomode',
#  'afirmacao presidente',
#  'afirmacao pretende',
#  'afirmacoes feitas',
#  'afirmacoes reconhece',
#  'afirmacoes rival',
#  'afirmado alusao',
#  'afirmado dilma',
#  'afirmando mantera',
#  'afirmar adversarios',
#  'afirmar marina',
#  'afirmar pt',
#  'afirmar quadro',
#  'afirmara ainda',
#  'afirmou acredita',
#  'afirmou acreditar',
#  'afirmou adversarios',
#  'afirmou alckmin',
#  'afirmou alianca',
#  'afirmou apos',
#  'afirmou apostaram',
#  'afirmou ate',
#  'afirmou candidata',
#  'afirmou cartao',
#  'afirmou certo',
#  'afirmou concorda',
#  'afirmou conversado',
#  'afirmou coordenador',
#  'afirmou desembarcar',
#  'afirmou desistiu',
#  'afirmou dialogo',
#  'afirmou doacoes',
#  'afirmou eleita',
#  'afirmou empresa',
#  'afirmou enquanto',
#  'afirmou entrevista',
#  'afirmou equipe',
#  'afirmou eventual',
#  'afirmou falar',
#  'afirmou familia',
#  'afirmou fara',
#  'afirmou gestoes',
#  'afirmou iniciativa',
#  'afirmou ja',
#  'afirmou mantera',
#  'afirmou melhor',
#  'afirmou nao',
#  'afirmou ninguem',
#  'afirmou novas',
#  'afirmou oficializacao',
#  'afirmou opcao',
#  'afirmou pediu',
#  'afirmou petista',
#  'afirmou pmdb',
#  'afirmou policiamento',
#  'afirmou politicos',
#  'afirmou possivel',
#  'afirmou pre',
#  'afirmou preciso',
#  'afirmou presidente',
#  'afirmou pretende',
#  'afirmou projeto',
#  'afirmou projetos',
#  'afirmou prosseguiu',
#  'afirmou referencia',
#  'afirmou relacao',
#  'afirmou ressaltou',
#  'afirmou sauer',
#  'afirmou senador',
#  'afirmou senadores',
#  'afirmou skaf',
#  'afirmou so',
#  'afirmou sofrendo',
#  'afirmou tambem',
#  'afirmou unico',
#  'afirmou vai',
#  'afirmou vice',
#  'afirmou visita',
#  'afonico afirma',
#  'afronta estado',
#  'afronta inteligencia',
#  'afundamento plataforma',
#  'afundar ninguem',
#  'afundou gestao',
#  'agencia estado',
#  'agencia moody',
#  'agencia questionado',
#  'agencia reguladora',
#  'agencia ressalvou',
#  'agencias reguladoras',
#  'agencias sao',
#  'agenda agenda',
#  'agenda ambiental',
#  'agenda boa',
#  'agenda candidato',
#  'agenda conjunta',
#  'agenda crivella',
#  'agenda diretamente',
#  'agenda duas',
#  'agenda importante',
#  'agenda liberal',
#  'agenda padilha',
#  'agenda pezao',
#  'agenda presidencial',
#  'agenda superboa',
#  'agentes inteligencias',
#  'agentes publicos',
#  'agilizar recebimento',
#  'agiplan financeira',
#  'agiu tomou',
#  'agnelo queiroz',
#  'ago pf',
#  'agora afirmou',
#  'agora candidata',
#  'agora chegou',
#  'agora cobramos',
#  'agora comeca',
#  'agora comigo',
#  'agora considerando',
#  'agora contra',
#  'agora discurso',
#  'agora espera',
#  'agora esperanca',
#  'agora faz',
#  'agora fazendo',
#  'agora financiado',
#  'agora gente',
#  'agora governar',
#  'agora ha',
#  'agora intencoes',
#  'agora investigacao',
#  'agora maior',
#  'agora maneira',
#  'agora marina',
#  'agora mensalao',
#  'agora metade',
#  'agora mudou',
#  'agora nao',
#  'agora pessoas',
#  'agora preferencia',
#  'agora quero',
#  'agora repetimos',
#  'agora sobre',
#  'agora tamanho',
#  'agora tapar',
#  'agora tentativa',
#  'agora tres',
#  'agora usado',
#  'agora vai',
#  'agora ve',
#  'agosto ano',
#  'agosto aparecido',
#  'agosto carta',
#  'agosto consequente',
#  'agosto desde',
#  'agosto entanto',
#  'agosto entao',
#  'agosto envolvidos',
#  'agosto estaria',
#  'agosto ex',
#  'agosto investigacoes',
#  'agosto ja',
#  'agosto ocasiao',
#  'agosto politica',
#  'agosto presidenta',
#  'agosto primeiro',
#  'agosto procuradores',
#  'agosto quantia',
#  'agosto quatro',
#  'agosto relatos',
#  'agosto subiu',
#  'agosto suposto',
#  'agosto veio',
#  'agosto voltem',
#  'agrada mercado',
#  'agradar taxistas',
#  'agradecendo deus',
#  'agradeceu senador',
#  'agrario ida',
#  'agrario miguel',
#  'agrario ressaltaram',
#  'agrava situacao',
#  'agredindo porque',
#  'agredir dilma',
#  'agredir mentir',
#  'agregado america',
#  'agressao boatos',
#  'agressao gosta',
#  'agressao ponderou',
#  'agressao rasteira',
#  'agressividade poupar',
#  'agressoes adversaria',
#  'agricultores familiares',
#  'agripino maia',
#  'agronegocio sempre',
#  'agrupamento votou',
#  'agua canos',
#  'agua carro',
#  'agua culpa',
#  'agua eleicao',
#  'agua parte',
#  'agua residencias',
#  'agua sao',
#  'agua tudo',
#  'aguardamos outras',
#  'aguardando investigacoes',
#  'aguardar informacoes',
#  'aguardavam vice',
#  'ai colocar',
#  'ai porque',
#  'ai sim',
#  'ai vivos',
#  'ainda acordo',
#  'ainda afirmou',
#  'ainda agenda',
#  'ainda apos',
#  'ainda aprovacao',
#  'ainda aproveitou',
#  'ainda assim',
#  'ainda ataca',
#  'ainda atitude',
#  'ainda bem',
#  'ainda brasil',
#  'ainda campanha',
#  'ainda cedo',
#  'ainda cenario',
#  'ainda comando',
#  'ainda comentou',
#  'ainda conversou',
#  'ainda criticou',
#  'ainda defender',
#  'ainda deixam',
#  'ainda demitiu',
#  'ainda depende',
#  'ainda destrinchando',
#  'ainda detalhes',
#  'ainda discurso',
#  'ainda disse',
#  'ainda divulgar',
#  'ainda eleita',
#  'ainda eleitor',
#  'ainda enfrenta',
#  'ainda estao',
#  'ainda estranha',
#  'ainda estranhar',
#  'ainda evento',
#  'ainda fato',
#  'ainda formalmente',
#  'ainda fundo',
#  'ainda furar',
#  'ainda gestoes',
#  'ainda governo',
#  'ainda ha',
#  'ainda hoje',
#  'ainda ideia',
#  'ainda igualdade',
#  'ainda interpelou',
#  'ainda ironizou',
#  'ainda janeiro',
#  'ainda lamentar',
#  'ainda lamentava',
#  'ainda maior',
#  'ainda manifestou',
#  'ainda marina',
#  'ainda ministro',
#  'ainda movimentadas',
#  'ainda mudanca',
#  'ainda nesta',
#  'ainda neste',
#  'ainda nunca',
#  'ainda petrobras',
#  'ainda pior',
#  'ainda podem',
#  'ainda poucos',
#  'ainda pretende',
#  'ainda punicao',
#  'ainda quer',
#  'ainda recebeu',
#  'ainda relacoes',
#  'ainda segundo',
#  'ainda sob',
#  'ainda sobre',
#  'ainda sp',
#  'ainda ter',
#  'ainda vice',
#  'ainda vulneravel',
#  'ajuda candidatura',
#  'ajuda presidente',
#  'ajuda redes',
#  'ajudar fazer',
#  'ajudar pais',
#  'ajudou dilma',
#  'ajuste preco',
#  'ajustes passou',
#  'al camara',
#  'al eduardo',
#  'al romero',
#  'al senadores',
#  'al tesoureiro',
#  'alardeada petrobras',
#  'alarmes cameras',
#  'alavancar candidatura',
#  'alberto youssef',
#  'albuquerque apos',
#  'albuquerque discurso',
#  'albuquerque disse',
#  'albuquerque enfatizaram',
#  'albuquerque presidente',
#  'albuquerque psb',
#  'albuquerque rebatido',
#  'alcada cabeca',
#  'alcada candidata',
#  'alcanca estado',
#  'alcanca outros',
#  'alcancar frente',
#  'alcancaremos numero',
#  'alckmin assegurou',
#  'alckmin candidato',
#  'alckmin desconversou',
#  'alckmin deu',
#  'alckmin exemplo',
#  'alckmin intitulada',
#  'alckmin nao',
#  'alckmin oscilou',
#  'alckmin peca',
#  'alckmin permanece',
#  'alckmin preferiu',
#  'alckmin promessas',
#  'alckmin recorre',
#  'alckmin rejeicao',
#  'alckmin restrito',
#  'alckmin sabesp',
#  'alckmin skaf',
#  'alckmin subiu',
#  'alckmin vence',
#  'alega adversaria',
#  'alegacao propaganda',
#  'alegado juiz',
#  'alegados petrobras',
#  'alegara ex',
#  'alegou apresenta',
#  'alegou deixou',
#  'alegou manter',
#  'alegou preciso',
#  'alegou propaganda',
#  'alegre cidade',
#  'alegre rs',
#  'aleluia anunciou',
#  'alem atacar',
#  'alem baixos',
#  'alem candidatos',
#  'alem comprometer',
#  'alem costa',
#  'alem declaracao',
#  'alem defesa',
#  'alem dois',
#  'alem ex',
#  'alem fronteiras',
#  'alem lideres',
#  'alem lindbergh',
#  'alem oas',
#  'alem poderem',
#  'alem pp',
#  'alem presidente',
#  'alem provocar',
#  'alem proximidade',
#  'alem relacao',
#  'alem rossetto',
#  'alem ter',
#  'alem vice',
#  'alemao mangueira',
#  'alemao vezes',
#  'alertar populacao',
#  'alertou fato',
#  'alexandre tombini',
#  'alfinetadas publicas',
#  'alfinetou candidata',
#  'alfinetou novamente',
#  'algo absolutamente',
#  'algo acontecera',
#  'algo anular',
#  'algo dessa',
#  'algo distante',
#  'algo parecido',
#  'algo tipo',
#  'algozes mandela',
#  'alguem cuja',
#  'alguem diz',
#  'alguem doze',
#  'alguem interprete',
#  'alguem nao',
#  'alguem poderoso',
#  'alguem pressionado',
#  'alguem psdb',
#  'alguem razao',
#  'alguem sabe',
#  'alguem vinha',
#  'algum malfeito',
#  'algum momento',
#  'algum programa',
#  'algum reu',
#  'alguma coisa',
#  'alguma nao',
#  'alguma vantagem',
#  'algumas companheiras',
#  'algumas dessas',
#  'algumas frases',
#  'algumas perguntas',
#  'algumas pessoas',
#  'algumas residencias',
#  'algumas semanas',
#  'algumas siglas',
#  'algumas vitorias',
#  'alguns casos',
#  'alguns dias',
#  'alguns dirigentes',
#  'alguns estados',
#  'alguns falam',
#  'alguns gerou',
#  'alguns morros',
#  'alguns nomes',
#  'alguns outros',
#  'alguns pontos',
#  'aliada inclusive',
#  'aliada presidente',
#  'aliada sido',
#  'aliado durante',
#  'aliados acusacoes',
#  'aliados compoem',
#  'aliados dilma',
#  'aliados ex',
#  'aliados governo',
#  'aliados presidenta',
#  'aliados presidente',
#  'aliados pt',
#  'alianca banqueiros',
#  'alianca marina',
#  'alianca proprio',
#  'alianca sociedade',
#  'aliancas direita',
#  'aliancas disputa',
#  'aliancas pt',
#  'alias orgaos',
#  'alice setubal',
#  'alicerce retomada',
#  'alinhamento politico',
#  'alinhando interesses',
#  'alinhavado suspeitas',
#  'aloca recurso',
#  'aloizio ministro',
#  'aloysio nunes',
#  'alta bolsa',
#  'alta densidade',
#  'alta inflacao',
#  'alta intencoes',
#  'alta precos',
#  'alta so',
#  'altas nesses',
#  'altas taxas',
#  'alteracao lgt',
#  'alteracoes ja',
#  'alterar cenario',
#  'alterar constituicao',
#  'alterar panorama',
#  'alterar sistema',
#  'alternado controle',
#  'alternativa marina',
#  'alternativa propor',
#  'alternativa ultima',
#  'alternativa viavel',
#  'alternativas economicas',
#  'alternativas energia',
#  'alterou programa',
#  'alterou voz',
#  'altissima qualidade',
#  'alto bem',
#  'alto corroendo',
#  'alto nivel',
#  'alto pagina',
#  'alto tiete',
#  'altos atual',
#  'altos controle',
#  'altos crescimento',
#  'altura campeonato',
#  'aluno fim',
#  'alusao paulo',
#  'alves rn',
#  'alvo adversarios',
#  'alvo diz',
#  'alvo militancia',
#  'alvo petista',
#  'alvo ser',
#  'alvorada brasilia',
#  'alvorada debater',
#  'alvorada liderancas',
#  'alvorada manha',
#  'alvorada ministro',
#  'alvorada petista',
#  'alvorada procurando',
#  'alvorada residencia',
#  'alvorada sabatina',
#  'alvorada sao',
#  'amado apoiado',
#  'amadores surpreende',
#  'amadurecer pouco',
#  'amai uns',
#  'amam si',
#  'amanha hoje',
#  'amanha ocorre',
#  'amar deus',
#  'amar uns',
#  'amaral criticou',
#  'amaral disse',
#  'amaral evento',
#  'amaral nota',
#  'amaral presidente',
#  'amarela metro',
#  'amarela pais',
#  'amargas poderiam',
#  'amazonas diz',
#  'amazonia aecio',
#  'amazonia fiscalizacao',
#  'ambas datafolha',
#  'ambas estrategias',
#  'ambas psb',
#  'ambientais cada',
#  'ambientais obras',
#  'ambiental insuficiente',
#  'ambiental tornou',
#  'ambientalista evitado',
#  'ambientalista falou',
#  'ambiente completa',
#  'ambiente conclamou',
#  ...]

# %%
from sklearn.feature_selection import VarianceThreshold, SelectKBest,chi2, mutual_info_classif
from sklearn.naive_bayes  import MultinomialNB
from sklearn.svm import SVC
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.pipeline import Pipeline
from nltk.corpus import stopwords

features = Pipeline([
                    ("lexicon_vector", CountVectorizer(strip_accents= "unicode", ngram_range=(1,2), stop_words=stopwords.words("portuguese"), vocabulary= selected)),
                    ("feature_selection", TruncatedSVD(n_components = 6000))
                    ])

run_cross_validation(all_data, features, LogisticRegressionCV(fit_intercept=False, penalty= 'l2', dual= False), n_folds = 10, shuffle= True)
# Out:
# Cross Validation:
# Accuracia media:  0.721806966618
# Desvio padrão:  0.0320216565807
